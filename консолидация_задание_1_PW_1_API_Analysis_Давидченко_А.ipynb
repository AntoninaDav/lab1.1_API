# %% [markdown]
# # Практическая работа 1. Сбор и анализ данных с использованием API
#
# **Дисциплина:** Анализ больших данных и рыночных тенденций
#
# **Направление:** Бизнес-информатика (магистратура)
#
# **вариант :** вариант 5
#
# Давидченко Антонина Сергеевна

# %% [markdown]
# ## Цель работы
#
# Получить углубленные навыки программного сбора и анализа данных из различных веб-источников с помощью API для решения прикладных бизнес-задач в области анализа больших данных, технологий и рыночных тенденций. Выполнение практического задания с kaggle api, github api, api hh.ru

# %% [markdown]
# ## программное обеспечение
# Python 3.x,
# Jupyter Notebook
#  Git

# %% [markdown]
# ## программное обеспечение
# requests, pandas, matplotlib, seaborn, kaggle, PyGithub.

# %% [markdown]
# ## Теоретическая часть
#
# **API (Application Programming Interface)** — это программный интерфейс, который позволяет двум приложениям обмениваться данными между собой. В контексте веб-сервисов API определяет набор правил и протоколов (чаще всего на базе HTTP/HTTPS), по которым разработчики могут получать доступ к данным или функциональности удаленного сервера.
#
# Для бизнес-информатика владение инструментами работы с API открывает доступ к огромным массивам актуальных данных, которые являются основой для принятия управленческих решений, анализа рынков, мониторинга конкурентов и выявления трендов.
#
# ### Основные принципы работы с API:
# 1.  **Аутентификация:** Большинство API требуют подтверждения личности пользователя. Обычно это реализуется через **ключи (API keys)** или **токены (tokens)**, которые необходимо включать в каждый запрос. Это позволяет сервису контролировать доступ и отслеживать использование.
# 2.  **Запросы (Requests):** Взаимодействие с API происходит путем отправки HTTP-запросов на определенные URL, называемые **конечными точками (endpoints)**. Каждый endpoint отвечает за определенный тип данных (например, `/users` для данных о пользователях).
# 3.  **Параметры:** Запросы можно настраивать с помощью параметров, которые передаются в URL (например, `?query=big data&per_page=100`), чтобы уточнить, какие именно данные нужны.
# 4.  **Ответы (Responses):** В ответ на запрос сервер возвращает данные, как правило, в структурированном формате, чаще всего **JSON (JavaScript Object Notation)**, который легко обрабатывается в большинстве языков программирования, включая Python.
#
# ### Используемые в работе API:
# *   **Kaggle API:** Предоставляет доступ к датасетам, соревнованиям и ноутбукам (kernels) на платформе Kaggle. Это ключевой источник данных для специалистов по Data Science и машинному обучению.
# *   **GitHub API:** Позволяет получать данные о репозиториях, пользователях, коммитах, issues и другой активности на GitHub — крупнейшей платформе для хостинга IT-проектов. Это ценный источник для анализа трендов в разработке ПО и технологических стеков.
# *   **HeadHunter (hh.ru) API:** Открывает доступ к одной из крупнейших в России баз данных вакансий и резюме. Незаменимый инструмент для анализа рынка труда, требований к специалистам и динамики зарплат.

# %% [markdown]
# ## Ход выполнения работы
#
# В данной работе мы выполним задания из **Варианта 5**:
# 1.  **Kaggle API:** Анализ авторов: найти топ-5 авторов (пользователей) по общему количеству голосов за их датасеты
# 2.  **GitHub API:** Анализ "форков": найти репозиторий tensorflow/tensorflow.Проанализировать последние 20 форков: кто и зачем их создает (анализ описаний)
# 3.  **hh.ru API:** География вакансий: сравнить количество вакансий по запросу "Big Data" в Москве и Санкт Петербурге

# %% [markdown]
# ### 1. Настройка окружения
#
# Сначала установим все необходимые библиотеки.

# %%
# !pip install -q kaggle requests pandas matplotlib seaborn

# %% [markdown]
# ---

# %% [markdown]
# ### Задание 1. Анализ топ-5 авторов (пользователей) по общему количеству голосов

# %% [markdown]
# #### 1.1. Аутентификация в Kaggle API
#
# 1.  Перейдите в свой профиль на Kaggle: `Моя учетная запись -> Settings -> API`.
# 2.  Нажмите **"Create New API Token"**. На ваш компьютер скачается файл `kaggle.json`.
# 3.  Загрузите этот файл в окружение Colab с помощью скрипта ниже.

# %%
from google.colab import files

# Пожалуйста, загрузите файл kaggle.json
files.upload()
# Out:
#      <input type="file" id="files-482616a0-98fc-4e57-87af-4c6bd0139331" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-482616a0-98fc-4e57-87af-4c6bd0139331">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Создаем директорию и копируем туда файл с токеном
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# #### 1.2. Сбор данных о топ-5 авторов (пользователей) по общему количеству голосов

# %% [markdown]
# # поля  для сбора данных
# # имя автора , кол-во голосов , название датасета

# %%
import kaggle
import pandas as pd

#Анализ авторов: найти топ-5 авторов (пользователей) по общему количеству голосов за их датасеты.


author = kaggle.api.dataset_list(sort_by='votes')

# %%
author
# Out:
# [{"id": 661950, "ref": "jessicali9530/animal-crossing-new-horizons-nookplaza-dataset", "subtitle": "A comprehensive inventory of ACNH items, villagers, clothing, fish/bugs etc", "creatorName": "Jessica Li", "creatorUrl": "jessicali9530", "totalBytes": 590770, "url": "https://www.kaggle.com/datasets/jessicali9530/animal-crossing-new-horizons-nookplaza-dataset", "lastUpdated": "2021-06-08T15:05:09.513Z", "downloadCount": 83126, "isPrivate": false, "isFeatured": false, "licenseName": "CC0: Public Domain", "description": "", "ownerName": "Jessica Li", "ownerRef": "jessicali9530", "kernelCount": 108, "title": "Animal Crossing New Horizons Catalog", "topicCount": 0, "viewCount": 988311, "voteCount": 55780, "currentVersionNumber": 3, "usabilityRating": 0.88235295, "tags": [{"ref": "simulations", "name": "simulations", "description": "", "fullPath": "subject > culture and humanities > games > video games > simulations", "competitionCount": 64, "datasetCount": 768, "scriptCount": 255, "totalC
# ...

# %%
# Преобразуем в DataFrame для удобства
df_author = pd.DataFrame([vars(c) for c in author])



# Выбираем топ-5 авторов (пользователей) по общему количеству голосов за их датасеты.
top_5 = df_author.head(5)

print("Топ-5 авторов по общему количеству голосов за их датасеты :")

print(top_5[['_creator_name','_title','_vote_count','_download_count']])
# Out:
# Топ-5 авторов по общему количеству голосов за их датасеты :
#    _creator_name                                             _title  \
# 0     Jessica Li               Animal Crossing New Horizons Catalog
# 1  Timo Bozsolik                        Credit Card Fraud Detection
# 2    Paul Mooney  COVID-19 Open Research Dataset Challenge (CORD...
# 3  Shivam Bansal                        Netflix Movies and TV Shows
# 4    Paul Mooney                     Chest X-Ray Images (Pneumonia)
#
#    _vote_count  _download_count
# 0        55780            83126
# 1        12693          1046133
# 2        11259           197709
# 3         9509           689919
# 4         7269           576917

# %% [markdown]
# #### 1.3. Анализ и визуализация данных
#
# Проанализируем полученные датасеты

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Настройка стиля для графиков
sns.set_style("whitegrid")

plt.figure(figsize=(12, 7))

# Используем столбцы: x='_vote_count' и y='_title'
sns.barplot(data=top_5, x='_vote_count', y='_title', )


plt.title('Количество голосов в топ 5 датасетах')
plt.xlabel('название датасета')
plt.ylabel('количество голосов')
plt.tight_layout() # Улучшает расположение элементов на графике
plt.show()

#Расположили названия по вертикали из-за длинного названия

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd



# Выводится только 4 автора , из-за того что seaborn по умолчанию агрегируют значения с одинковыми именами

# проводим подготовку данных

# создаём порядковый номер для повторяющихся имён
counts = top_5.groupby('_creator_name').cumcount() + 1

# Формируем уникальные имена если автор повторяется, добавляем (2) для уникальности имени
top_5['unique_name'] = top_5['_creator_name']  # сначала копируем имена
top_5.loc[counts > 1, 'unique_name'] = top_5.loc[counts > 1, '_creator_name'] + ' (' + counts.astype(str) + ')'


# Настройка стиля
sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.barplot(data=top_5, x='unique_name', y='_vote_count', palette='Set1')

plt.title('Количество голосов в топ 5 датасетах')
plt.xlabel('имя автора')
plt.ylabel('количество голосов')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-1746299643.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_5['unique_name'] = top_5['_creator_name']  # сначала копируем имена
# /tmp/ipython-input-1746299643.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5, x='unique_name', y='_vote_count',    palette='Set1')

# %%
# визуализация датасеты по количеству скачиваний
sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.barplot(data=top_5, x='_title', y='_download_count', palette='Set1')

plt.title('Количество скачиваний в топ 5 датасетах')
plt.xlabel('имя автора')
plt.ylabel('количество скачиваний')
plt.xticks(rotation=70)
plt.show()
# Out:
# /tmp/ipython-input-2461141927.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5, x='_title', y='_download_count', palette='Set1')

# %% [markdown]
# #### 1.4. Выводы по Заданию 1
#
# С помощью Kaggle API мы успешно получили список датасетов с наибольшими голосами. Анализ показывает, что  датасет "Animal Crossing New Horizons Catalog" лидирует по голосам, но самый скачиваемый датасет " Credit Card Fraud Detection"

# %% [markdown]
# ---

# %% [markdown]
# ### Задание 2.  Анализ "форков": найти репозиторий tensorflow/tensorflow Проанализировать последние 20 форков: кто и зачем их создает(анализ описаний).

# %% [markdown]
# #### 2.1. Аутентификация в GitHub API
#
# 1.  Перейдите на страницу [генерации токенов в GitHub](https://github.com/settings/tokens/new).
# 2.  Создайте новый токен (classic) с правами доступа `public_repo`. Установите срок действия (например, 7 дней).
# 3.  **Обязательно скопируйте токен!** После закрытия страницы он больше не будет показан. Вставьте его в переменную `ACCESS_TOKEN` ниже.

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd


ACCESS_TOKEN = "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"
GITHUB_API_URL = "https://api.github.com"

headers = {
    "Authorization": f"token {ACCESS_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

# %% [markdown]
# #### 2.2. Поиск репозитория и сбор данных о коммитах

# %%
# Поиск репозитория
query = "tensorflow/tensorflow"
params = {"q": query, "sort": "stars", "order": "desc"}



response = requests.get(f"{GITHUB_API_URL}/search/repositories", params=params, headers=headers)
repo_data = response.json()['items'][0]
repo_full_name = repo_data['full_name']

print(f"Самый популярный репозиторий: {repo_full_name}")
print(f"Количество звезд: {repo_data['stargazers_count']}")

# Получение последних 20 форков
forks_url = f"{GITHUB_API_URL}/repos/{repo_full_name}/forks"
forks_params = {"per_page": 20, "sort": "newest"}
forks_response = requests.get(forks_url, headers=headers, params=forks_params)
forks_data = forks_response.json()

#Сбор последних 20 форков
df = pd.DataFrame([{
    "owner": fork['owner']['login'],
    "description": fork['description'] if fork['description'] else ""
} for fork in forks_data])

print(f"Последние 20 форков:\n{df.head(20)}")
# Out:
# Самый популярный репозиторий: tensorflow/tensorflow
# Количество звезд: 192705
# Последние 20 форков:
#                        owner  \
# 0               SachaDev34FR
# 1             812235364-tech
# 2              Mrlonewolf296
# 3                 derricka20
# 4         iiIfeiithetechnerd
# 5                  kasdthieu
# 6           SorunEngineering
# 7             RohitYandigeri
# 8            yongwei9527-art
# 9   hernandez1234anna-dotcom
# 10                 mb-shupto
# 11               joeyye-work
# 12              Mohataseem89
# 13             afshin-paydar
# 14                Harshid001
# 15             Brucesquared2
# 16           Raghavendrapara
# 17                DAChughtai
# 18               omkarrr2533
# 19                  chinanuj
#
#                                           description
# 0   An Open Source Machine Learning Framework for ...
# 1   An Open Source Machine Learning Framework for ...
# 2   An Open Source Machine Learning Framework for ...
# ...

# %% [markdown]
# #### 2.3. Анализ и визуализация форков

# %%
df.head(20)
# Out:
#                        owner  \
# 0               SachaDev34FR
# 1             812235364-tech
# 2              Mrlonewolf296
# 3                 derricka20
# 4         iiIfeiithetechnerd
# 5                  kasdthieu
# 6           SorunEngineering
# 7             RohitYandigeri
# 8            yongwei9527-art
# 9   hernandez1234anna-dotcom
# 10                 mb-shupto
# 11               joeyye-work
# 12              Mohataseem89
# 13             afshin-paydar
# 14                Harshid001
# 15             Brucesquared2
# 16           Raghavendrapara
# 17                DAChughtai
# 18               omkarrr2533
# 19                  chinanuj
#
#                                           description
# 0   An Open Source Machine Learning Framework for ...
# 1   An Open Source Machine Learning Framework for ...
# 2   An Open Source Machine Learning Framework for ...
# 3   An Open Source Machine Learning Framework for ...
# 4   An Open Source Machine Learning Framework for ...
# ...

# %%
import matplotlib.pyplot as plt

# Горизонтальная столбчатая диаграмма
df['owner'].value_counts().head(20).plot(kind='barh', figsize=(12,8))
plt.title("Владельцы последних 20 форков")
plt.xlabel("Количество форков")
plt.ylabel("Владелец")
plt.gca().invert_yaxis()  # чтобы самый большой столбец был сверху
plt.show()

# %%
description_counts = df['description'].value_counts()

plt.figure(figsize=(12,6))
description_counts.plot(kind='bar')
plt.ylabel("Количество")
plt.xlabel("Описание форка")
plt.title("Количество одинаковых описаний форков")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### 2.4. Выводы по Заданию 2
#
# Используя GitHub API, нашли репозитории с названием tensorflow/te
# nsorflow и проанализировали последние 20 форков: кто и зачем их создает. Визуализация показывает, что сделанные последние 20 форков имеют одинаковое описание. Скорее всего , одинаковое описание форков связано с тем что , данное описание используется по умолчанию.

# %% [markdown]
# ---

# %% [markdown]
# ### Задание 3. Анализ География вакансий на hh.ru

# %% [markdown]
# #### 3.1. Работа с API hh.ru
#
# API HeadHunter не требует сложной аутентификации для поиска вакансий, что упрощает задачу. Мы будем отправлять GET-запросы к эндпоинту `/vacancies`.

# %%
import time
import requests

HH_API_URL = "https://api.hh.ru/vacancies"

pages_to_load = 5 # 100 вакансий (по 20 на странице)

moscow = []

params = {
    'text': 'Big Data',
    'area': 1, # Москва
    'per_page': 20
}

for page in range(pages_to_load):
    params['page'] = page
    response = requests.get(HH_API_URL, params=params)
    if response.status_code == 200:
        vacancies_data = response.json()
        moscow.extend(vacancies_data['items'])
        print(f"Загружена страница {page + 1}/{pages_to_load} в Москве ")
    else:
        print(f"Ошибка при загрузке страницы {page + 1}: {response.status_code}")
        break
    time.sleep(0.2) # Соблюдаем вежливость к API

print(f"\nВсего найдено вакансий в Москве : {len(moscow)}")


spb = []

for page in range(pages_to_load):
    params = {
        'text': 'Big Data',
        'area': 2,       # Санкт-Петербург
        'per_page': 20,
        'page': page
    }
    response = requests.get(HH_API_URL, params=params)
    if response.status_code == 200:
        data = response.json()
        spb.extend(data['items'])
        print(f"Загружена страница {page + 1}/{pages_to_load} для Санкт-Петербурга")
    else:
        print(f"Ошибка при загрузке страницы {page+1} для Санкт-Петербурга")
        break
    time.sleep(0.2)

print(f"Всего вакансий в Санкт-Петербурге: {len(spb)}")
# Out:
# Загружена страница 1/5 в Москве
# Загружена страница 2/5 в Москве
# Загружена страница 3/5 в Москве
# Загружена страница 4/5 в Москве
# Загружена страница 5/5 в Москве
#
# Всего найдено вакансий в Москве : 100
# Загружена страница 1/5 для Санкт-Петербурга
# Загружена страница 2/5 для Санкт-Петербурга
# Загружена страница 3/5 для Санкт-Петербурга
# Загружена страница 4/5 для Санкт-Петербурга
# Загружена страница 5/5 для Санкт-Петербурга
# Всего вакансий в Санкт-Петербурге: 76

# %% [markdown]
# #### 3.2. Визуализация результатов

# %%
import matplotlib.pyplot as plt

cities = ['Москва', 'Санкт-Петербург']
vacancies = [len(moscow), len(spb)]


plt.bar(cities, vacancies, color=['blue', 'red'])
plt.title('Количество вакансий по запросу "Big Data"')
plt.ylabel('Количество вакансий')
plt.xlabel('Город')
plt.show()

# %% [markdown]
# #### 3.3. Выводы по Заданию 3
#
# После проведенного анализ вакансий для big data в Москве и Санкт Петербурге с помощью hh.ru API, можно сделать вывод, что в Москве больше вакансий, из за большего количества it-компаний. В Санкт-Петербурге количество вакансий меньше, но всё равно остаётся значительным. Такая информация является ценной для соискателей, чтобы они могли планировать поиск работы в Москве, для образовательных учреждений для изменения учебной программы.

# %% [markdown]
# ---

# %% [markdown]
# ## Общий вывод по работе
#
# В ходе выполнения данной практической работы были получены углубленные навыки программного сбора и анализа данных с использованием API трех различных платформ: Kaggle, GitHub и hh.ru. Научились проходить аутентификацию, отправлять параметризованные запросы, обрабатывать и структурировать полученные JSON-ответы, а также визуализировать результаты для их наглядной интерпретации.
#
# **Основные полученные навыки:**
# - Работа с `kaggle` API для анализа данных об авторах (пользователей) пообщему количеству голосов за их датасеты.
# - Работа с github API для поиска репозиториев по теме tensorflow/tensorflow.Проанализированы последние 20 форков: кто и зачем их создает .
# - Работа с `hh` API для анализа данных об вакансиях big data и их количество в москве и санкт петербурге.
# - Обработка и анализ данных с помощью библиотеки `pandas`.
# - Визуализация результатов с помощью `matplotlib` и `seaborn`.
#
# **Возникшие трудности и способы их решения:**
# - **агрегирование в seaborn:** по умолчанию агрегируются значения с одинковыми именами, решение посредством добавления числа к одинаковым значениям, для создания уникальных значений
# - **Ограничения API (Rate Limiting):** при частом обращении к API можно столкнуться с лимитами на количество запросов. Проблема решалась введением небольших пауз (`time.sleep()`) между запросами.
# - **Неструктурированные данные:** данные, полученные через API, требовали предварительной очистки и преобразования (например, очистка призового фонда в Kaggle, приведение навыков к нижнему регистру в hh.ru), что подчеркивает важность этапа подготовки данных (Data Wrangling).
#
# Данная работа наглядно демонстрирует, как с помощью API можно автоматизировать сбор актуальных данных и проводить на их основе прикладные бизнес-исследования, будь то анализ рыночных тенденций, оценка популярности технологий или мониторинг рынка труда.
